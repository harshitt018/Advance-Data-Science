# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitt018/Advance-Data-Science/blob/main/LSTM_and_RNN_on_Google_Stock_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("medharawat/google-stock-price")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/medharawat/google-stock-price?dataset_version_number=1...
# 100%|██████████| 23.4k/23.4k [00:00<00:00, 39.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/medharawat/google-stock-price/versions/1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import warnings

warnings.filterwarnings("ignore")
tf.random.set_seed(42)
np.random.seed(42)

# Load datasets
train_df = pd.read_csv("/root/.cache/kagglehub/datasets/medharawat/google-stock-price/versions/1/Google_Stock_Price_Train.csv")
test_df = pd.read_csv("/root/.cache/kagglehub/datasets/medharawat/google-stock-price/versions/1/Google_Stock_Price_Test.csv")

# Columns to clean
cols = ['Open', 'High', 'Low', 'Close', 'Volume']
for df in [train_df, test_df]:
    df[cols] = df[cols].apply(lambda x: x.astype(str).str.replace(',', '').astype(float))

# %%
def add_technical_indicators(df):
    df['MA_10'] = df['Close'].rolling(window=10).mean()
    df['MA_20'] = df['Close'].rolling(window=20).mean()

    # RSI calculation
    delta = df['Close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=14).mean()
    avg_loss = loss.rolling(window=14).mean()
    rs = avg_gain / avg_loss
    df['RSI'] = 100 - (100 / (1 + rs))

    df.fillna(method='bfill', inplace=True)
    return df

train_df = add_technical_indicators(train_df)
test_df = add_technical_indicators(test_df)

feature_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'MA_10', 'MA_20', 'RSI']
train_df = train_df[feature_cols]
test_df = test_df[feature_cols]

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_df)
test_scaled = scaler.transform(test_df)

def create_sequences(data, seq_len=60):
    X, y_price, y_dir = [], [], []
    for i in range(seq_len, len(data)):
        X.append(data[i-seq_len:i])
        y_price.append(data[i, 0])
        y_dir.append(1 if data[i, 0] > data[i-1, 0] else 0)
    return np.array(X), np.array(y_price), np.array(y_dir)

SEQ_LEN = 60
X_train, y_train_price, y_train_dir = create_sequences(train_scaled, SEQ_LEN)

# Adjust SEQ_LEN if test data is smaller
SEQ_LEN_test = min(SEQ_LEN, len(test_scaled)-1)
X_test, y_test_price, y_test_dir = create_sequences(test_scaled, SEQ_LEN_test)

print(f"Train sequences: {X_train.shape}, Test sequences: {X_test.shape}")
# Out:
# Train sequences: (1198, 60, 8), Test sequences: (1, 19, 8)

# %%
def build_price_model(model_type='LSTM'):
    model = Sequential()
    if model_type == 'LSTM':
        model.add(LSTM(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(LSTM(32))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
    elif model_type == 'RNN':
        model.add(SimpleRNN(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(SimpleRNN(32))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
    model.add(Dense(1))
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    return model

def build_direction_model(model_type='LSTM'):
    model = Sequential()
    if model_type == 'LSTM':
        model.add(LSTM(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(LSTM(32))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
    elif model_type == 'RNN':
        model.add(SimpleRNN(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(SimpleRNN(32))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Price Prediction Training
print("Training LSTM Price Prediction Model...")
history_lstm_price = model_lstm.fit(
    X_train, y_train_price,
    epochs=30, batch_size=32,
    validation_split=0.1,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)

print("Training RNN Price Prediction Model...")
history_rnn_price = model_rnn.fit(
    X_train, y_train_price,
    epochs=30, batch_size=32,
    validation_split=0.1,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)

# Direction Classification Training
print("Training LSTM Direction Classification Model...")
history_lstm_dir = model_lstm_dir.fit(
    X_train, y_train_dir,
    epochs=30, batch_size=32,
    validation_split=0.1,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)

print("Training RNN Direction Classification Model...")
history_rnn_dir = model_rnn_dir.fit(
    X_train, y_train_dir,
    epochs=30, batch_size=32,
    validation_split=0.1,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)
# Out:
# Training LSTM Price Prediction Model...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 2.0145 - val_loss: 0.3415 - learning_rate: 0.0010
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.2680 - val_loss: 0.2461 - learning_rate: 0.0010
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1147 - val_loss: 0.1424 - learning_rate: 0.0010
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.8939 - val_loss: 0.1760 - learning_rate: 0.0010
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.7945 - val_loss: 0.1147 - learning_rate: 0.0010
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7143 - val_loss: 0.1150 - learning_rate: 0.0010
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6431 - val_loss: 0.0839 - learning_rate: 0.0010
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5456 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4768 - val_loss: 0.0313 - learning_rate: 0.0010
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4010 - val_loss: 0.0566 - learning_rate: 0.0010
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3643 - val_loss: 0.0166 - learning_rate: 0.0010
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3103 - val_loss: 0.0392 - learning_rate: 0.0010
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2895 - val_loss: 0.0197 - learning_rate: 0.0010
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2528 - val_loss: 0.0293 - learning_rate: 0.0010
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2256 - val_loss: 0.0155 - learning_rate: 0.0010
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2182 - val_loss: 0.0423 - learning_rate: 0.0010
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1839 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1496 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1370 - val_loss: 0.0186 - learning_rate: 0.0010
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1375 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1144 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0965 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0966 - val_loss: 0.0106 - learning_rate: 0.0010
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0739 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0726 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0611 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0586 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 28/30
# 31/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0512
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0508 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0488 - val_loss: 0.0071 - learning_rate: 7.0000e-04
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0471 - val_loss: 0.0076 - learning_rate: 7.0000e-04
# Training RNN Price Prediction Model...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - loss: 1.2751 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7675 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5330 - val_loss: 0.0286 - learning_rate: 0.0010
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4074 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3304 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 6/30
# 31/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3096
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3058 - val_loss: 0.0505 - learning_rate: 0.0010
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2248 - val_loss: 0.0331 - learning_rate: 7.0000e-04
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2095 - val_loss: 0.0331 - learning_rate: 7.0000e-04
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2205 - val_loss: 0.0282 - learning_rate: 7.0000e-04
# Training LSTM Direction Classification Model...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.4879 - loss: 0.9483 - val_accuracy: 0.4750 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5442 - loss: 0.7954 - val_accuracy: 0.5083 - val_loss: 0.6929 - learning_rate: 0.0010
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5060 - loss: 0.7802 - val_accuracy: 0.5083 - val_loss: 0.6929 - learning_rate: 0.0010
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4873 - loss: 0.8019 - val_accuracy: 0.5083 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4706 - loss: 0.7907 - val_accuracy: 0.5083 - val_loss: 0.6982 - learning_rate: 0.0010
# Epoch 6/30
# 32/34 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5057 - loss: 0.7547
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5070 - loss: 0.7541 - val_accuracy: 0.5083 - val_loss: 0.6940 - learning_rate: 0.0010
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5259 - loss: 0.7400 - val_accuracy: 0.5083 - val_loss: 0.6924 - learning_rate: 7.0000e-04
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5535 - loss: 0.7165 - val_accuracy: 0.5000 - val_loss: 0.6929 - learning_rate: 7.0000e-04
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5281 - loss: 0.7378 - val_accuracy: 0.4833 - val_loss: 0.6925 - learning_rate: 7.0000e-04
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5209 - loss: 0.7247 - val_accuracy: 0.5333 - val_loss: 0.6915 - learning_rate: 7.0000e-04
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5382 - loss: 0.7406 - val_accuracy: 0.5417 - val_loss: 0.6920 - learning_rate: 7.0000e-04
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5545 - loss: 0.7177 - val_accuracy: 0.5417 - val_loss: 0.6917 - learning_rate: 7.0000e-04
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5245 - loss: 0.7377 - val_accuracy: 0.5250 - val_loss: 0.6924 - learning_rate: 7.0000e-04
# Epoch 14/30
# 29/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4822 - loss: 0.7579
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4882 - loss: 0.7551 - val_accuracy: 0.4917 - val_loss: 0.6965 - learning_rate: 7.0000e-04
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4922 - loss: 0.7433 - val_accuracy: 0.5333 - val_loss: 0.6930 - learning_rate: 4.9000e-04
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4882 - loss: 0.7328 - val_accuracy: 0.5167 - val_loss: 0.6934 - learning_rate: 4.9000e-04
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5191 - loss: 0.7239 - val_accuracy: 0.4917 - val_loss: 0.6944 - learning_rate: 4.9000e-04
# Training RNN Direction Classification Model...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.4575 - loss: 0.9099 - val_accuracy: 0.5083 - val_loss: 0.7369 - learning_rate: 0.0010
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5069 - loss: 0.8021 - val_accuracy: 0.5083 - val_loss: 0.7115 - learning_rate: 0.0010
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5031 - loss: 0.7893 - val_accuracy: 0.5083 - val_loss: 0.6983 - learning_rate: 0.0010
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4973 - loss: 0.7660 - val_accuracy: 0.5333 - val_loss: 0.6913 - learning_rate: 0.0010
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5016 - loss: 0.7461 - val_accuracy: 0.4917 - val_loss: 0.6914 - learning_rate: 0.0010
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5536 - loss: 0.7168 - val_accuracy: 0.5667 - val_loss: 0.6897 - learning_rate: 0.0010
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5533 - loss: 0.7123 - val_accuracy: 0.5083 - val_loss: 0.6877 - learning_rate: 0.0010
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5251 - loss: 0.7364 - val_accuracy: 0.5250 - val_loss: 0.6946 - learning_rate: 0.0010
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5143 - loss: 0.7386 - val_accuracy: 0.5333 - val_loss: 0.6982 - learning_rate: 0.0010
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5635 - loss: 0.7044 - val_accuracy: 0.6500 - val_loss: 0.6797 - learning_rate: 0.0010
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5265 - loss: 0.7401 - val_accuracy: 0.6583 - val_loss: 0.6746 - learning_rate: 0.0010
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5618 - loss: 0.7003 - val_accuracy: 0.5583 - val_loss: 0.6917 - learning_rate: 0.0010
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5721 - loss: 0.7008 - val_accuracy: 0.5417 - val_loss: 0.6826 - learning_rate: 0.0010
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5831 - loss: 0.6926 - val_accuracy: 0.5083 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 15/30
# 31/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5829 - loss: 0.6808
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5849 - loss: 0.6795 - val_accuracy: 0.5333 - val_loss: 0.6806 - learning_rate: 0.0010
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6039 - loss: 0.6833 - val_accuracy: 0.5500 - val_loss: 0.6750 - learning_rate: 7.0000e-04
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6323 - loss: 0.6529 - val_accuracy: 0.5500 - val_loss: 0.6726 - learning_rate: 7.0000e-04
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5857 - loss: 0.6793 - val_accuracy: 0.7417 - val_loss: 0.6309 - learning_rate: 7.0000e-04
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5878 - loss: 0.6812 - val_accuracy: 0.5833 - val_loss: 0.6562 - learning_rate: 7.0000e-04
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5863 - loss: 0.6931 - val_accuracy: 0.7083 - val_loss: 0.6179 - learning_rate: 7.0000e-04
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6336 - loss: 0.6446 - val_accuracy: 0.6833 - val_loss: 0.6217 - learning_rate: 7.0000e-04
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6248 - loss: 0.6433 - val_accuracy: 0.6667 - val_loss: 0.6333 - learning_rate: 7.0000e-04
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6394 - loss: 0.6418 - val_accuracy: 0.6500 - val_loss: 0.6371 - learning_rate: 7.0000e-04
# Epoch 24/30
# 31/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6285 - loss: 0.6596
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6284 - loss: 0.6589 - val_accuracy: 0.5750 - val_loss: 0.6834 - learning_rate: 7.0000e-04
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6444 - loss: 0.6311 - val_accuracy: 0.6667 - val_loss: 0.6299 - learning_rate: 4.9000e-04
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6673 - loss: 0.6140 - val_accuracy: 0.5917 - val_loss: 0.6717 - learning_rate: 4.9000e-04
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6504 - loss: 0.6318 - val_accuracy: 0.7000 - val_loss: 0.6186 - learning_rate: 4.9000e-04

# %%
# Predict direction
pred_lstm_dir = (model_lstm_dir.predict(X_test) > 0.5).astype(int).flatten()
pred_rnn_dir = (model_rnn_dir.predict(X_test) > 0.5).astype(int).flatten()

# Accuracy
acc_lstm_dir = accuracy_score(y_test_dir, pred_lstm_dir)
acc_rnn_dir = accuracy_score(y_test_dir, pred_rnn_dir)

print(f"LSTM Direction Accuracy: {acc_lstm_dir*100:.2f}%")
print(f"RNN Direction Accuracy: {acc_rnn_dir*100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# LSTM Direction Accuracy: 100.00%
# RNN Direction Accuracy: 100.00%
