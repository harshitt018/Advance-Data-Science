# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitt018/Advance-Data-Science/blob/main/Simple%20YOLO%20Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt
import glob

model = YOLO("yolov8s.pt")

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d6686b4-df49-4fc1-8b5e-feb41ac0189c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d6686b4-df49-4fc1-8b5e-feb41ac0189c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]

results = model.predict(
    source=image_path,
    conf=0.25,
    save=True
)
# Out:
# image 1/1 /content/images.jpg: 352x640 1 person, 13 cars, 4 buss, 8 trucks, 910.9ms
# Speed: 17.4ms preprocess, 910.9ms inference, 42.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to /content/runs/detect/predict

# %%
result_img = glob.glob("runs/detect/predict/*.jpg")[0]

img = Image.open(result_img)

plt.figure(figsize=(12,8))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
uploaded = files.upload()

video_path = list(uploaded.keys())[0]

model.predict(
    source=video_path,
    save=True
)
# Out:
#      <input type="file" id="files-07dc608e-97d3-4158-a7cd-5b5f98e2e020" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07dc608e-97d3-4158-a7cd-5b5f98e2e020">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

for root, dirs, files in os.walk("runs/detect"):
    for file in files:
        if file.endswith(".mp4"):
            print(os.path.join(root, file))

# %%
from google.colab import files

files.download(
    "runs/detect/predict/Mumbai ka Traffic  Mumbai Traffic  India #shorts.avi"
)
